# %% [markdown]
# # **Level** **1**

# %%
import pandas as pd
data= pd.read_csv('/content/sample_data/Dataset .csv')
data
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
data.shape
# Out:
# (9551, 21)

# %%
def enc(df):
  label_encoder = LabelEncoder()
  columns_to_drop = []
  for col in df.select_dtypes(include=['object']).columns:
      print(f"Processing column: {col}")
      if df[col].isnull().any():
          print(f"Column {col} contains NaN values. Fill NaNs or drop rows before encoding.")
          continue
      try:
          df[col + '_encoded'] = label_encoder.fit_transform(df[col])
          columns_to_drop.append(col)
          print(f"Column {col} encoded successfully.")
      except Exception as e:
          print(f"Failed to encode column {col}: {e}")
  df.drop(columns=columns_to_drop, inplace=True)
  print("Original columns dropped successfully.")
  return df

# %%
from sklearn.preprocessing import LabelEncoder
data=enc(data)
# Out:
# Processing column: Restaurant Name
# Column Restaurant Name encoded successfully.
# Processing column: City
# Column City encoded successfully.
# Processing column: Address
# Column Address encoded successfully.
# Processing column: Locality
# Column Locality encoded successfully.
# Processing column: Locality Verbose
# Column Locality Verbose encoded successfully.
# Processing column: Cuisines
# Column Cuisines contains NaN values. Fill NaNs or drop rows before encoding.
# Processing column: Currency
# Column Currency encoded successfully.
# Processing column: Has Table booking
# Column Has Table booking encoded successfully.
# Processing column: Has Online delivery
# Column Has Online delivery encoded successfully.
# Processing column: Is delivering now
# Column Is delivering now encoded successfully.
# Processing column: Switch to order menu
# Column Switch to order menu encoded successfully.
# Processing column: Rating color
# Column Rating color encoded successfully.
# ...

# %%
data.dropna
data
# Out:
#       Restaurant ID  Country Code   Longitude   Latitude  \
# 0           6317637           162  121.027535  14.565443
# 1           6304287           162  121.014101  14.553708
# 2           6300002           162  121.056831  14.581404
# 3           6318506           162  121.056475  14.585318
# 4           6314302           162  121.057508  14.584450
# ...             ...           ...         ...        ...
# 9546        5915730           208   28.977392  41.022793
# 9547        5908749           208   29.041297  41.009847
# 9548        5915807           208   29.034640  41.055817
# 9549        5916112           208   29.036019  41.057979
# 9550        5927402           208   29.026016  40.984776
#
#                               Cuisines  Average Cost for two  Price range  \
# 0           French, Japanese, Desserts                  1100            3
# 1                             Japanese                  1200            3
# ...

# %%
cuisine_series = data['Cuisines'].str.split(', ').explode()
cuisine_counts = cuisine_series.value_counts()

# Get the top three cuisines
top_three_cuisines = cuisine_counts.head(3)

top_three_cuisines
# Out:
# Cuisines
# North Indian    3960
# Chinese         2735
# Fast Food       1986
# Name: count, dtype: int64

# %%
ni = data.loc[data['Cuisines'] == 'North Indian']
ni_per = ((ni.shape[0])/data.shape[0]*100)
chi=data.loc[data['Cuisines']=='Chinese']
chi_per=((chi.shape[0])/data.shape[0]*100)
ff=data.loc[data['Cuisines']=='Fast Food']
ff_per=((ff.shape[0])/data.shape[0]*100)
print(f"the percentage of North Indian cuisine among all cuisines was {ni_per:.3f} %")
print(f"the percentage of Chinese cuisine among all cuisines was {chi_per:.3f} %")
print(f"the percentage of Fast Food cuisine among all cuisines was {ff_per:.3f} %")
# Out:
# the percentage of North Indian cuisine among all cuisines was 9.800 %
# the percentage of Chinese cuisine among all cuisines was 3.706 %
# the percentage of Fast Food cuisine among all cuisines was 3.706 %

# %%
high_city=data.value_counts('City')
high_city.head(3)
# Out:
# City
# New Delhi    5473
# Gurgaon      1118
# Noida        1080
# Name: count, dtype: int64

# %%
len_data=data.shape[0]

# %%
average_ratings_by_city = (data.groupby('City')['Aggregate rating'].mean()).sort_values(ascending=False)
l=average_ratings_by_city.head(1)
print(f"the city with highest average rating is {l.index[0]}")
# Out:
# the city with highest average rating is Inner City

# %%
import matplotlib.pyplot as plt
price_range_counts = data['Price range'].value_counts()
plt.bar(price_range_counts.index, price_range_counts.values)
plt.xlabel('Price Range')
plt.ylabel('Number of Restaurants')
plt.title('Distribution of Price Ranges')
plt.show()

# %%
price_range_rest=data.groupby('Price range')['Restaurant ID'].count()
price_range_rest_count=price_range_rest.count()
price_range_rest_count
price_range_rest
# Out:
# Price range
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: Restaurant ID, dtype: int64

# %%
for i in range (price_range_rest_count):
   print(f'the percentange of restaurant at price range {i+1} was {price_range_rest.values[i]/data.shape[0]*100:.3f}% respectively ')
# Out:
# the percentange of restaurant at price range 1 was 46.529% respectively
# the percentange of restaurant at price range 2 was 32.593% respectively
# the percentange of restaurant at price range 3 was 14.742% respectively
# the percentange of restaurant at price range 4 was 6.135% respectively

# %%
on_delv=data.loc[data['Has Online delivery']=='Yes']
per_on_delv=((on_delv.shape[0])/data.shape[0]*100)
print(f'The percentage of restaurants that offer online delivery was {per_on_delv:.2f}%')
# Out:
# The percentage of restaurants that offer online delivery was 25.66%

# %%
on_delv_rating=data.groupby('Has Online delivery')['Aggregate rating'].mean()
print(f'the average rating for restaurants that offer online delivery is {on_delv_rating.values[0]:.2f}')
print(f'the average rating for restaurants that do not offer online delivery is {on_delv_rating.values[1]:.2f}')
print(f'the difference between those two is {on_delv_rating.values[1]-on_delv_rating.values[0]:.2f}')
# Out:
# the average rating for restaurants that offer online delivery is 2.47
# the average rating for restaurants that do not offer online delivery is 3.25
# the difference between those two is 0.78

# %% [markdown]
# ### **Level** **3**

# %%
votes=data['Votes']
votes.max()
votes.min()
h_rest=data.loc[data['Votes']==votes.max()]
l_rest=data.loc[data['Votes']==votes.min()]
print(f'the highest rated restaurant is {h_rest.values[0,1]}')
print(f'the lowest rated restaurant is {l_rest.values[0,1]}')
# Out:
# the highest rated restaurant is 1
# the lowest rated restaurant is 30

# %%
data_corr=data['Aggregate rating'],data['Votes']
cor=data_corr[0].corr(data_corr[1])
print(f'the correlation between aggregate rating and votes is {cor:.2f} \nSo there is relation between them but that will not have much impacts on each other')
# Out:
# the correlation between aggregate rating and votes is 0.31
# So there is relation between them but that will not have much impacts on each other

# %%
data_corr_2=data['Price range'],data['Has Table booking_encoded'],data['Has Online delivery_encoded']
data_corr_2=pd.DataFrame(data_corr_2).transpose()
cor_2=data_corr_2.corr()
cor_2
# Out:
#                              Price range  Has Table booking_encoded  \
# Price range                     1.000000                   0.501925
# Has Table booking_encoded       0.501925                   1.000000
# Has Online delivery_encoded     0.077918                   0.101224
#
#                              Has Online delivery_encoded
# Price range                                     0.077918
# Has Table booking_encoded                       0.101224
# Has Online delivery_encoded                     1.000000

# %%
print(f'there is a somehow strong relation between "price range" and "Has Table booking" \nSince they has correlation of {cor_2.values[0,1]:.3f} \nWhen compared with other correlations')
# Out:
# there is a somehow strong relation between "price range" and "Has Table booking"
# Since they has correlation of 0.502
# When compared with other correlations

# %%
high_price_rest=data.loc[data['Average Cost for two']>2000]
high_price_rest.shape[0]
# Out:
# 258

# %%
does_offer_online_delivery=high_price_rest.loc[high_price_rest['Has Online delivery_encoded']==1]
does_offer_online_delivery.shape[0]
does_offer_Table_booking=high_price_rest.loc[high_price_rest['Has Table booking_encoded']==1]
does_offer_Table_booking.shape[0]
does_offer_both=does_offer_online_delivery.loc[does_offer_online_delivery['Has Table booking_encoded']==1]
does_offer_both
does_offer=does_offer_both
does_offer.shape[0]
# Out:
# 17

# %%
print(f'By choosing restaurants where the cost above 2000 as high priced restaurants\nSo there are {high_price_rest.shape[0]} restaurants\nIn those restaurants {does_offer_online_delivery.shape[0]} offers online delivery, which was {does_offer_online_delivery.shape[0]/high_price_rest.shape[0]*100:.2f}% of the high priced restaurants\nAnd {does_offer_Table_booking.shape[0]} offers table booking which was {does_offer_Table_booking.shape[0]/high_price_rest.shape[0]*100:.2f}% of the high priced restaurants \nFinaly there are {does_offer.shape[0]} offers both services among high priced restaurants and that was {does_offer.shape[0]/high_price_rest.shape[0]*100:.2f}% of the high priced restaurants \nConclusion: From our assumption of high price restaurants(price above 2000) {does_offer.shape[0]/high_price_rest.shape[0]*100:.3f}% restaurants only gives both services')
# Out:
# By choosing restaurants where the cost above 2000 as high priced restaurants
# So there are 258 restaurants
# In those restaurants 17 offers online delivery, which was 6.59% of the high priced restaurants
# And 180 offers table booking which was 69.77% of the high priced restaurants
# Finaly there are 17 offers both services among high priced restaurants and that was 6.59% of the high priced restaurants
# Conclusion: From our assumption of high price restaurants(price above 2000) 6.589% restaurants only gives both services
